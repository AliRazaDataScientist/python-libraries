# %%
import numpy as np
import pandas as pd

# %%
rec = pd.read_csv('UpdatedFile.csv')

# %%
rec
# Out:
#   Student Name   Subject  Marks
# 0        Hasan      Data     42
# 1         Qaim      Urdu     50
# 2        Qamer   Biology     54
# 3      Ibrahim  Computer     55
# 4          Ali   Biology     23
# 5        Ahmad   English      1
# 6       Ghyass      Math     44
# 7       Tabish   Physics     22

# %%
rec.iloc[4,[1,2]]=['Urdu',58]

# %%
rec
# Out:
#   Student Name   Subject Marks
# 0        Hasan      Data    42
# 1         Qaim      Urdu    50
# 2        Qamer   Biology    54
# 3      Ibrahim  Computer    55
# 4          Ali      Urdu    58
# 5        Ahmad   English     1
# 6       Ghyass      Math    44
# 7       Tabish   Physics    22

# %%
rec.loc[(rec['Marks']>=50) & (rec['Subject'] == 'Urdu'),['Student Name','Marks']]
# Out:
#   Student Name Marks
# 1         Qaim    50
# 4          Ali    58

# %%
rec[(rec['Marks']>45) & (rec['Subject'].str.contains('Urdu'))][['Student Name','Marks']]
# Out:
#   Student Name Marks
# 1         Qaim    50
# 4          Ali    58

# %%
rec[(rec['Subject'].str.contains(r'u|H',case=False))]
# Out:
#   Student Name   Subject Marks
# 1         Qaim      Urdu    50
# 3      Ibrahim  Computer    55
# 4          Ali      Urdu    58
# 5        Ahmad   English     1
# 6       Ghyass      Math    44
# 7       Tabish   Physics    22

# %%
rec['Pass/Fail'] = np.where(rec['Marks']>45,'P','F')

# %%
rec['Result'] = np.where(rec['Marks']>45,'Pass','Fail')

# %%
rec.drop(columns=['Pass/Fail'])
# rec.drop(0)
# Out:
#   Student Name   Subject  Marks Result
# 0        Hasan      Data     42   Fail
# 1         Qaim      Urdu     50   Pass
# 2        Qamer   Biology     54   Pass
# 3      Ibrahim  Computer     55   Pass
# 4          Ali   Biology     23   Fail
# 5        Ahmad   English      1   Fail
# 6       Ghyass      Math     44   Fail
# 7       Tabish   Physics     22   Fail

# %%
rec
# Out:
#   Student Name   Subject  Marks Pass/Fail Result
# 0        Hasan      Data     42         F   Fail
# 1         Qaim      Urdu     50         P   Pass
# 2        Qamer   Biology     54         P   Pass
# 3      Ibrahim  Computer     55         P   Pass
# 4          Ali   Biology     23         F   Fail
# 5        Ahmad   English      1         F   Fail
# 6       Ghyass      Math     44         F   Fail
# 7       Tabish   Physics     22         F   Fail

# %%
rec.drop(columns=['Pass/Fail'],inplace=True)

# %%
rec
# Out:
#   Student Name   Subject  Marks Result
# 0        Hasan      Data     42   Fail
# 1         Qaim      Urdu     50   Pass
# 2        Qamer   Biology     54   Pass
# 3      Ibrahim  Computer     55   Pass
# 4          Ali   Biology     23   Fail
# 5        Ahmad   English      1   Fail
# 6       Ghyass      Math     44   Fail
# 7       Tabish   Physics     22   Fail

# %%
rec.to_csv('abcd.csv', index=False)

# %%
rec[['Student Name','Marks','Subject','Result']]
# Out:
#   Student Name  Marks   Subject Result
# 0        Hasan     42      Data   Fail
# 1         Qaim     50      Urdu   Pass
# 2        Qamer     54   Biology   Pass
# 3      Ibrahim     55  Computer   Pass
# 4          Ali     23   Biology   Fail
# 5        Ahmad      1   English   Fail
# 6       Ghyass     44      Math   Fail
# 7       Tabish     22   Physics   Fail
