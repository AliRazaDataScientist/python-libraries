# %%
import pandas as pd

# %%
coffee = pd.read_csv('F_Marks.csv')

# %%
coffee
# Out:
#   Student Name   Subject  Marks
# 0        Hasan      Data     42
# 1         Qaim      Urdu     46
# 2        Qamer   Biology     54
# 3      Ibrahim  Computer     55

# %%
olympicsdata = pd.read_excel('./file_data/olympics_data.xlsx')

# %%
olympicsdata.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
results_parquet = pd.read_parquet('./file_data/results.parquet')

# %%
results_parquet.tail()
# Out:
#           year    type              discipline                          event  \
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                    None        Slalom, Women (Olympic)
#
#                           as  athlete_id   noc    team  place   tied medal
# 308403         Marián Skupek      148983   SVK    None   26.0  False  None
# 308404         Elsa Fermbäck      148984   SWE    None   28.0  False  None
# 308405         Hilma Lövblom      148985   SWE  Sweden   13.0  False  None
# 308406         Hilma Lövblom      148985   SWE    None    NaN  False  None
# 308407  Charlotta Säfvenberg      148986  None    None   24.0  False  None

# %%
bios = pd.read_csv('./file_data/bios.csv')

# %%
bios.sample(10)
# Out:
#         athlete_id                name   born_date        born_city  \
# 24281        24470          Luc Mbassi  1957-01-01          Yaoundé
# 113402      114693        Josh McAdams  1980-03-26          Atlanta
# 29644        29869  Charles Ballossier  1878-03-21        Montrouge
# 96888        97667     Miloslav Sochor  1952-01-08  Pec pod Sněžkou
# 107993      109134         Pan Tzu-Hui  1983-01-08          Nantong
# 47593        47944         Horst Weber  1939-08-20         Bayreuth
# 36025        36310    Franklin Zielski  1941-03-01          Welland
# 22410        22579     Michael O'Brien  1969-12-23              NaN
# 80083        80734        Susan Broman  1959-07-28         Helsinki
# 118434      120149        Azza Alqasmi  1985-02-12            Riffa
#
#                  born_region born_country             NOC  height_cm  \
# 24281                 Centre          CMR        Cameroon        NaN
# 113402               Georgia          USA   United States      175.0
# ...

# %%
bios.loc[[5,9],['name','NOC']]
# Out:
#                  name     NOC
# 5   Nicolas Chatelain  France
# 9  Guy de la Chapelle  France

# %%
bios.iloc[0:5,[1,6]]
# Out:
#                     name     NOC
# 0  Jean-François Blanchy  France
# 1         Arnaud Boetsch  France
# 2           Jean Borotra  France
# 3        Jacques Brugnon  France
# 4           Albert Canet  France

# %%
bios.loc[0:5,['NOC','born_city']]= ['PK','PK']

# %%
xyz = bios[(bios['height_cm']>165) & (bios['born_country'] == 'USA')][['name','born_date','NOC','born_country']]

# %%
xyz.to_excel('xyz.xlsx', index=False)

# %%
bios[bios['name'].str.contains('Ali', case=False)][['name','NOC']]
# Out:
#                         name            NOC
# 9                        ali         France
# 18                       Ali         France
# 41                       ali  Great Britain
# 47                       ali  Great Britain
# 48             Alison Gordon  Great Britain
# ...                      ...            ...
# 145201           Alina Meier    Switzerland
# 145235          Natalie Maag    Switzerland
# 145335  Vitaliy Kalinichenko        Ukraine
# 145457        Alix Wilkinson  United States
# 145465     Stanislav Galiyev            ROC
#
# [2265 rows x 2 columns]

# %%
bios[bios['born_date'].str.contains(r'^19', na=False)]
# Out:
# Empty DataFrame
# Columns: [athlete_id, name, born_date, born_city, born_region, born_country, NOC, height_cm, weight_kg, died_date]
# Index: []

# %%
bios.query('name == "ali"')
# Out:
#     athlete_id name   born_date          born_city born_region born_country  \
# 9           10  ali  1868-07-16  Farges-Allichamps        Cher          FRA
# 41          42  ali    9/2/1961            Baghdad     Baghdad          IRQ
# 47          48  ali   5/13/1964            Torquay     England          GBR
#
#               NOC  height_cm  weight_kg  died_date
# 9          France        NaN        NaN  8/27/1923
# 41  Great Britain      176.0       68.0        NaN
# 47  Great Britain      190.0       85.0        NaN

# %%
bios[bios['name'].str.startswith("Ali")]
# Out:
#         athlete_id             name   born_date      born_city  born_region  \
# 18              19              Ali  1882-11-15          Vichy       Allier
# 48              49    Alison Gordon  12/31/1962        Reading      England
# 49              50             Alii    4/9/1964            NaN          NaN
# 50              51     Alice Greene  1879-10-15          Upton      England
# 279            280  Ali Athar Fyzee  1883-08-28         Mumbai  Maharashtra
# ...            ...              ...         ...            ...          ...
# 144705      148405   Alia Eichinger   7/19/2001        Freyung       Bayern
# 144943      148651   Alina Stremous   7/11/1995    Kotelnikovo    Volgograd
# 145071      148783  Alina Kovalyova   2/18/1993        Slantsy    Leningrad
# 145201      148919      Alina Meier   2/19/1996          Davos   Graubünden
# 145457      149183   Alix Wilkinson    8/2/2000  Mammoth Lakes   California
#
# ...

# %%
bios[bios['born_city'].isin(['Davos'])]
# Out:
#         athlete_id               name   born_date born_city born_region  \
# 37710        38008       Paul Söllner    6/5/1911     Davos  Graubünden
# 49815        50173   Nicolas Gilliard  10/27/1947     Davos  Graubünden
# 79856        80507     Martina Accola    3/8/1969     Davos  Graubünden
# 80090        80741     Silvia Brunner   1/17/1958     Davos  Graubünden
# 82503        83156        Paul Accola   2/20/1967     Davos  Graubünden
# 82920        83578        Joos Ambühl  10/23/1959     Davos  Graubünden
# 83268        83926         Gian Bazzi    4/3/1931     Davos  Graubünden
# 83407        84068        Franz Berry  11/21/1938     Davos  Graubünden
# 83717        84381     Mario Brodmann    4/2/1966     Davos  Graubünden
# 84694        85370         Hans Dürst   6/28/1921     Davos  Graubünden
# 84695        85371       Walter Dürst    6/4/1950     Davos  Graubünden
# 84696        85372  Walter Paul Dürst   2/28/1927     Davos  Graubünden
# ...
