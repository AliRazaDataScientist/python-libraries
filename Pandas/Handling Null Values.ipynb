# %%
import pandas as pd
import numpy as np

# %%
read = pd.read_csv('UpdatedFile.csv')

# %%
read.loc[[1,2,5],'Marks'] = np.nan
read.head(6)
# Out:
#   Student Name   Subject  Marks
# 0        Hasan      Data   42.0
# 1         Qaim      Urdu    NaN
# 2        Qamer   Biology    NaN
# 3      Ibrahim  Computer   55.0
# 4          Ali   Biology   23.0
# 5        Ahmad   English    NaN

# %%
read.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Student Name  8 non-null      object
#  1   Subject       8 non-null      object
#  2   Marks         5 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 324.0+ bytes

# %%
read.isna().sum()
# Out:
# Student Name    0
# Subject         0
# Marks           0
# dtype: int64

# %%
read.fillna(read['Marks'].mean())
# Out:
#   Student Name   Subject  Marks
# 0        Hasan      Data   42.0
# 1         Qaim      Urdu   37.2
# 2        Qamer   Biology   37.2
# 3      Ibrahim  Computer   55.0
# 4          Ali   Biology   23.0
# 5        Ahmad   English   37.2
# 6       Ghyass      Math   44.0
# 7       Tabish   Physics   22.0

# %%
read
# Out:
#   Student Name   Subject  Marks
# 0        Hasan      Data   42.0
# 1         Qaim      Urdu    NaN
# 2        Qamer   Biology    NaN
# 3      Ibrahim  Computer   55.0
# 4          Ali   Biology   23.0
# 5        Ahmad   English    NaN
# 6       Ghyass      Math   44.0
# 7       Tabish   Physics   22.0

# %%
read['Marks'] = read['Marks'].interpolate()

# %%
read
# Out:
#   Student Name   Subject      Marks
# 0        Hasan      Data  42.000000
# 1         Qaim      Urdu  46.333333
# 2        Qamer   Biology  50.666667
# 3      Ibrahim  Computer  55.000000
# 4          Ali   Biology  23.000000
# 5        Ahmad   English  33.500000
# 6       Ghyass      Math  44.000000
# 7       Tabish   Physics  22.000000

# %%
replace = read.dropna()
# read
replace
# Out:
#   Student Name   Subject  Marks
# 0        Hasan      Data   42.0
# 3      Ibrahim  Computer   55.0
# 4          Ali   Biology   23.0
# 6       Ghyass      Math   44.0
# 7       Tabish   Physics   22.0

# %%
isna = read[read['Marks'].isna()]
isna
# Out:
#   Student Name  Subject  Marks
# 1         Qaim     Urdu    NaN
# 2        Qamer  Biology    NaN
# 5        Ahmad  English    NaN

# %%
isna = read[read['Marks'].notna()]
isna
# Out:
#   Student Name   Subject  Marks
# 0        Hasan      Data   42.0
# 3      Ibrahim  Computer   55.0
# 4          Ali   Biology   23.0
# 6       Ghyass      Math   44.0
# 7       Tabish   Physics   22.0
